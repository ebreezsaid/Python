# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load digits dataset :
digits = datasets.load_digits()
x = digits.data

# %%
#Standardize the features to have mean=0 and variance=1 :
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
X[]

# %%
# To show it as drawing :
plt.figure(figsize=[1,1])
plt.imshow(np.array(x[7]).reshape(8,8))
plt.show()

# %%
# Apply PCA [] and fit the features selected :
pca = PCA(n_components=2)
X_pca=pca.fit_transform(x_scaled)

#visualizethe data
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0],X_pca[:,1],c=digits.target,alpha=0.5,cmap=plt.cm.get_cmap('GnBu',10))
plt.colorbar()
plt.xlabel('first principal component')
plt.ylabel('second principal component')
plt.title('PCA on Digits Dataset')
plt.show()
# Out:
# <ipython-input-9-36de66c71a72>:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.scatter(X_pca[:,0],X_pca[:,1],c=digits.target,alpha=0.5,cmap=plt.cm.get_cmap('GnBu',10))

# %%
print('Explained Variance',pca.explained_variance_ratio_)
# Out:
# Explained Variance [0.12033916 0.09561054]
